# %%
from experiment import Experiment
import sys
# Out:
# [nltk_data] Downloading package punkt to /home/juh079/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
exp_name = 'default'
exp = Experiment(exp_name)
# Out:
# loading annotations into memory...
# Done (t=0.93s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.62s)
# creating index...
# index created!
# Using the saved vocab.
# loading annotations into memory...
# Done (t=0.98s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.95s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.46s)
# creating index...
# index created!
# Using the saved vocab.
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /tmp/xdg-cache/torch/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 97.8M/97.8M [00:06<00:00, 15.7MB/s]
# Using GPU

# %% [markdown]
# testing baseline default embedding size

# %%
exp.test(0.1)
# Out:
# loading annotations into memory...
# Done (t=0.48s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a zebra standing in a field next to a bush ., actual: an image of a lone zebra eating grass
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4101700062447406, Bleu1: 90.7056634088988, Bleu4: 46.52144766978124
# (2.4101700062447406, 90.7056634088988, 46.52144766978124)

# %%
exp.test(0.2)
# Out:
# loading annotations into memory...
# Done (t=0.44s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a plate of food with a fork and a spoon ., actual: a plate with meat and vegetables next to a fork.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.410249632977425, Bleu1: 90.64640895415617, Bleu4: 46.10925026409709
# (2.410249632977425, 90.64640895415617, 46.10925026409709)

# %%
exp.test(0.7)
# Out:
# loading annotations into memory...
# Done (t=0.39s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a man is sitting down and using a laptop ., actual: a man sitting in front of a computer holding a camera wearing headphones
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4102299071372824, Bleu1: 89.9386384431609, Bleu4: 38.464690612714314
# (2.4102299071372824, 89.9386384431609, 38.464690612714314)

# %%
exp.test(1.5)
# Out:
# loading annotations into memory...
# Done (t=0.52s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: directional edge pictures churning roof up at night stand ., actual: a traffic sign hung upside down on a pole.
# Length of true sentences = 15011, length of predicted sentences = 15182
# Test Performance: Loss: 2.4102880163395657, Bleu1: 77.77664442580785, Bleu4: 7.4070015886901475
# (2.4102880163395657, 77.77664442580785, 7.4070015886901475)

# %%
exp.test(2.0)
# Out:
# loading annotations into memory...
# Done (t=0.68s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: happy stop at department bicyclists benedict dunkin asbestos yard advertisement carving outdoors system 24 '' damaged crossing thrown stop, actual: a close up of a country sign, the picture is a personified bus that is freaking out because it is about to hit a biker, and the sign below reads 'danger traversee de route'.
# Length of true sentences = 15011, length of predicted sentences = 16045
# Test Performance: Loss: 2.4110149890818495, Bleu1: 62.7805147109419, Bleu4: 4.618043179664464
# (2.4110149890818495, 62.7805147109419, 4.618043179664464)

# %%
exp.test(1.0)
# Out:
# loading annotations into memory...
# Done (t=0.42s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a pizza , a burger with sausage meats and sauces sauce ., actual: table with a platter of pizza and a plate with a slice.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4106599006247014, Bleu1: 88.09722606745014, Bleu4: 28.407211425551942
# (2.4106599006247014, 88.09722606745014, 28.407211425551942)

# %%
exp.test(3.0)
# Out:
# loading annotations into memory...
# Done (t=0.66s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: knees booth weekend barbeque past carving mice rocker filed metropolis nearby dispensers stripes materials ; divided handling beef be colorful, actual: a bathroom sink shapped like a glass bowl.
# Length of true sentences = 15011, length of predicted sentences = 15328
# Test Performance: Loss: 2.4097077116053156, Bleu1: 53.44711765635511, Bleu4: 3.4982786892457707
# (2.4097077116053156, 53.44711765635511, 3.4982786892457707)

# %%
exp.test(5.0)
# Out:
# loading annotations into memory...
# Done (t=0.43s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: observe designing vane floyd supply blanketed of pull calculators a fist weather ambulance award handles hooked earbuds these placemat messing, actual: a stop sign is the focal point of an intersection that is covered in snow during the winter.
# Length of true sentences = 15011, length of predicted sentences = 15022
# Test Performance: Loss: 2.410454231627444, Bleu1: 51.12461543768517, Bleu4: 3.1864742331691494
# (2.410454231627444, 51.12461543768517, 3.1864742331691494)

# %%
exp.test(1.1)
# Out:
# loading annotations into memory...
# Done (t=0.45s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a little girl is playing a video game with a set ., actual: a little girl stands on one leg as she plays with a remote while another person lounges in the background on a couch.
# Length of true sentences = 15011, length of predicted sentences = 15015
# Test Performance: Loss: 2.4102389761742127, Bleu1: 85.3374074997299, Bleu4: 12.379378789186038
# (2.4102389761742127, 85.3374074997299, 12.379378789186038)

# %%
exp.test(1.2)
# Out:
# loading annotations into memory...
# Done (t=0.38s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a stop sign sitting in front of an urban area flooring street ., actual: a large red stop sign next to a box sitting on a sidewalk.
# Length of true sentences = 15011, length of predicted sentences = 15017
# Test Performance: Loss: 2.410150044015113, Bleu1: 84.4443762527515, Bleu4: 12.720271455713444
# (2.410150044015113, 84.4443762527515, 12.720271455713444)

# %%
exp.test(1.3)
# Out:
# loading annotations into memory...
# Done (t=0.40s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: there are indian students that are posing ., actual: a woman guiding a horse that is pulling a carriage
# Length of true sentences = 15011, length of predicted sentences = 15040
# Test Performance: Loss: 2.4107511682713287, Bleu1: 82.70146569331541, Bleu4: 9.875804538002878
# (2.4107511682713287, 82.70146569331541, 9.875804538002878)

# %%
exp.test(0.01)
# Out:
# loading annotations into memory...
# Done (t=0.39s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a plate of food with a sandwich and french fries ., actual: a plate of food which includes onions, tomato, lettuce, sauce, fries, and a sandwich.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4099232988154635, Bleu1: 90.65709458256572, Bleu4: 46.72618950925646
# (2.4099232988154635, 90.65709458256572, 46.72618950925646)

# %%
exp.test(0.05)
# Out:
# loading annotations into memory...
# Done (t=0.40s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a man and a woman are standing in a room ., actual: a bride and groom posing by a tree
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4104573036761994, Bleu1: 90.66462511604976, Bleu4: 46.69957365130063
# (2.4104573036761994, 90.66462511604976, 46.69957365130063)

# %% [markdown]
# ## testing other embedding sizes

# %%
model100 = "experiment_data/best_modelbaseline_0.0005_30_100.pt"
model200 = "experiment_data/best_modelbaseline_0.0005_30_200.pt"
model300 = "experiment_data/best_modelbaseline_0.0005_30_300.pt"
model400 = "experiment_data/best_modelbaseline_0.0005_30_400.pt"

# %%
from model_factory import get_model

config_data = {
    "experiment_name": "baseline_deterministic",
    "model": 
    {
        "hidden_size": 512,
        "embedding_size": 100,
        "model_type": "RNN"
    },
    "dataset": 
    {
        "training_annotation_file_path": "./data/annotations/captions_train2014.json",
        "vocabulary_threshold": 2,
    },
}
# print(dir(exp))
exp._Experiment__encoder_model, exp._Experiment__decoder_model = get_model(config_data, exp._Experiment__vocab)
exp._Experiment__encoder_model = exp._Experiment__encoder_model.cuda()
exp._Experiment__decoder_model = exp._Experiment__decoder_model.cuda()
# Out:
# Using the saved vocab.

# %%
exp.test(0.1, model100)
# Out:
# loading annotations into memory...
# Done (t=0.46s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a group of people on skis standing in the snow ., actual: a man and a woman are in the snow with helmets.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.433550416662338, Bleu1: 90.88522526936417, Bleu4: 47.656244791396546
# (2.433550416662338, 90.88522526936417, 47.656244791396546)

# %%
exp.test(0.2, model100)
# Out:
# loading annotations into memory...
# Done (t=0.31s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a street sign that has been defaced ., actual: a sign for a state fair is under a street sign.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4332406343297754, Bleu1: 90.84676159114909, Bleu4: 47.38655386860921
# (2.4332406343297754, 90.84676159114909, 47.38655386860921)

# %%
exp.test(0.7, model100)
# Out:
# loading annotations into memory...
# Done (t=0.35s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a stop sign that has been vandalized in the center ., actual: a white demon hovering next to a red stop sign under a one way street sign.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.433351714560326, Bleu1: 90.1235168063614, Bleu4: 39.229788076850596
# (2.433351714560326, 90.1235168063614, 39.229788076850596)

# %%
exp.test(1.0, model100)
# Out:
# loading annotations into memory...
# Done (t=0.33s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a close up of a white clock on the wall ., actual: a very tall church with a clock below a tower.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.433159310766991, Bleu1: 88.42804243765413, Bleu4: 29.2350405390429
# (2.433159310766991, 88.42804243765413, 29.2350405390429)

# %%
exp.test(1.5, model100)
# Out:
# loading annotations into memory...
# Done (t=0.28s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: three men that are playing the engaging game ., actual: a living room with wooden floors filled with furniture.
# Length of true sentences = 15011, length of predicted sentences = 15032
# Test Performance: Loss: 2.4334717405603286, Bleu1: 79.72555844970253, Bleu4: 8.625085106336456
# (2.4334717405603286, 79.72555844970253, 8.625085106336456)

# %%
exp.test(2.0, model100)
# Out:
# loading annotations into memory...
# Done (t=0.34s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: hotdog , gravy heart along wearing pepperoni , containers word breaded wallpaper ? variety jack meat . no delicate, actual: two pizzas on wooden plates on a table with a pizza cutter and drinks
# Length of true sentences = 15011, length of predicted sentences = 15599
# Test Performance: Loss: 2.4333904925813066, Bleu1: 67.06342216313156, Bleu4: 5.391063242438782
# (2.4333904925813066, 67.06342216313156, 5.391063242438782)

# %%
config_data["model"]["embedding_size"] = 200
exp._Experiment__encoder_model, exp._Experiment__decoder_model = get_model(config_data, exp._Experiment__vocab)
exp._Experiment__encoder_model = exp._Experiment__encoder_model.cuda()
exp._Experiment__decoder_model = exp._Experiment__decoder_model.cuda()
# Out:
# Using the saved vocab.

# %%
exp.test(0.1, model200)
# Out:
# loading annotations into memory...
# Done (t=0.29s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a man is walking on the beach with a surfboard ., actual: a couple of people flying kites on top of a beach.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4116330501881054, Bleu1: 90.99046651371775, Bleu4: 47.111483530845646
# (2.4116330501881054, 90.99046651371775, 47.111483530845646)

# %%
exp.test(0.2, model200)
# Out:
# loading annotations into memory...
# Done (t=0.30s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a bathroom with a toilet , sink and a toilet ., actual: the interior of a bathroom with crumpled and torn toilet paper on the floor along with a toilet roll that has been pulled.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.412076612229043, Bleu1: 90.89017067829182, Bleu4: 46.80152098094931
# (2.412076612229043, 90.89017067829182, 46.80152098094931)

# %%
exp.test(0.7, model200)
# Out:
# loading annotations into memory...
# Done (t=0.46s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a group of sheep grazing on a green hillside ., actual: a sheep stands alert with it's face to the camera while it's offspring, head hidden by the sheep's wool, drinks it's mother's milk.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4122230763131, Bleu1: 89.99373202738342, Bleu4: 38.83603534458413
# (2.4122230763131, 89.99373202738342, 38.83603534458413)

# %%
exp.test(1.0, model200)
# Out:
# loading annotations into memory...
# Done (t=0.29s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a bathroom contains two public transportation , a sink , and mirror on the counter ., actual: a white colored vanity area with a mirror, sink and double light on the wall above the mirror.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4120723866401836, Bleu1: 88.34419208912796, Bleu4: 28.8160156222256
# (2.4120723866401836, 88.34419208912796, 28.8160156222256)

# %%
exp.test(1.5, model200)
# Out:
# loading annotations into memory...
# Done (t=0.30s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: four people in taxiing evidence high together draft skateboarders, actual: a man standing next to a small airplane with two dogs.
# Length of true sentences = 15011, length of predicted sentences = 15048
# Test Performance: Loss: 2.412017004540626, Bleu1: 78.80789426989008, Bleu4: 7.936143374368308
# (2.412017004540626, 78.80789426989008, 7.936143374368308)

# %%
exp.test(2.0, model200)
# Out:
# loading annotations into memory...
# Done (t=0.33s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: position ending climbing crying right wearing pavement, actual: a young man in a suit with his arm around the shoulder a shorter older man, also in a suit
# Length of true sentences = 15011, length of predicted sentences = 15672
# Test Performance: Loss: 2.411952437745764, Bleu1: 65.2074705829247, Bleu4: 5.046910986429905
# (2.411952437745764, 65.2074705829247, 5.046910986429905)

# %%
config_data["model"]["embedding_size"] = 300
config_data["model"]["hidden_size"] = 256
exp._Experiment__encoder_model, exp._Experiment__decoder_model = get_model(config_data, exp._Experiment__vocab)
exp._Experiment__encoder_model = exp._Experiment__encoder_model.cuda()
exp._Experiment__decoder_model = exp._Experiment__decoder_model.cuda()
# Out:
# Using the saved vocab.

# %%
exp.test(0.1, model300)
# Out:
# loading annotations into memory...
# Done (t=0.38s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a large brown horse standing in a field ., actual: a few large animals in a desert with a sky background
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.440311245208091, Bleu1: 90.19752773760843, Bleu4: 46.17468371598078
# (2.440311245208091, 90.19752773760843, 46.17468371598078)

# %%
exp.test(0.2, model300)
# Out:
# loading annotations into memory...
# Done (t=0.42s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a person holding a sandwich in a kitchen ., actual: a man who is eating a pizza and looking out a window.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.439439377886184, Bleu1: 90.19566686602278, Bleu4: 45.67462245838762
# (2.439439377886184, 90.19566686602278, 45.67462245838762)

# %%
exp.test(0.7, model300)
# Out:
# loading annotations into memory...
# Done (t=0.43s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a line of police bikes parked beside a fire hydrant ., actual: a group of people riding on the backs of motorcycles.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.4397929130716527, Bleu1: 89.6641378342649, Bleu4: 37.85539125795221
# (2.4397929130716527, 89.6641378342649, 37.85539125795221)

# %%
exp.test(1.0, model300)
# Out:
# loading annotations into memory...
# Done (t=0.40s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a dead healthy bird sitting on a wide in a car ., actual: a man standing on a sidewalk next to an rv
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.439670595209649, Bleu1: 88.04821166291485, Bleu4: 27.70355782500816
# (2.439670595209649, 88.04821166291485, 27.70355782500816)

# %%
exp.test(1.5, model300)
# Out:
# loading annotations into memory...
# Done (t=0.42s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: exact installing the clock on the wall bed a neighborhood christmas stands view multi-lane calves ., actual: a round window showing a man's face in the upper corner of a building.
# Length of true sentences = 15011, length of predicted sentences = 15019
# Test Performance: Loss: 2.439443559849516, Bleu1: 79.42174942109988, Bleu4: 8.755474506387152
# (2.439443559849516, 79.42174942109988, 8.755474506387152)

# %%
exp.test(2.0, model300)
# Out:
# loading annotations into memory...
# Done (t=0.42s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: pussy haze legs rails are stairs leading three moped counter with umbrellas waiting city ., actual: a man holding an umbrella while walking down a street.
# Length of true sentences = 15011, length of predicted sentences = 15216
# Test Performance: Loss: 2.439455970804742, Bleu1: 66.15188482069053, Bleu4: 5.289807375051255
# (2.439455970804742, 66.15188482069053, 5.289807375051255)

# %%
config_data["model"]["embedding_size"] = 400
config_data["model"]["hidden_size"] = 512
exp._Experiment__encoder_model, exp._Experiment__decoder_model = get_model(config_data, exp._Experiment__vocab)
exp._Experiment__encoder_model = exp._Experiment__encoder_model.cuda()
exp._Experiment__decoder_model = exp._Experiment__decoder_model.cuda()
# Out:
# Using the saved vocab.

# %%
exp.test(0.1, model400)
# Out:
# loading annotations into memory...
# Done (t=0.34s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a man standing in front of a kitchen counter with a cake ., actual: a man standing with a glass in his hand.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.3947378645551964, Bleu1: 90.78229083169535, Bleu4: 46.733805723105625
# (2.3947378645551964, 90.78229083169535, 46.733805723105625)

# %%
exp.test(0.2, model400)
# Out:
# loading annotations into memory...
# Done (t=0.59s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a double decker bus driving down a street ., actual: a white bus driving down a street next to power line.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.3941307341798823, Bleu1: 90.63410455973495, Bleu4: 46.25609594470347
# (2.3941307341798823, 90.63410455973495, 46.25609594470347)

# %%
exp.test(0.7, model400)
# Out:
# loading annotations into memory...
# Done (t=0.41s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a young soccer player dribbling the ball during the day ., actual: a baseball player holding a bat next to a base.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.3939386235906723, Bleu1: 89.98678786521609, Bleu4: 38.595188235869514
# (2.3939386235906723, 89.98678786521609, 38.595188235869514)

# %%
exp.test(1.0, model400)
# Out:
# loading annotations into memory...
# Done (t=0.41s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: a bicycle pulling a wagon filled with piles of bicycles ., actual: a bicycle leaning up against a tree in a park.
# Length of true sentences = 15011, length of predicted sentences = 15011
# Test Performance: Loss: 2.3934484015119835, Bleu1: 88.19143679601186, Bleu4: 28.41795323390699
# (2.3934484015119835, 88.19143679601186, 28.41795323390699)

# %%
exp.test(1.5, model400)
# Out:
# loading annotations into memory...
# Done (t=0.44s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: there is standing waiting for chute placed ., actual: a close up of a country sign, the picture is a personified bus that is freaking out because it is about to hit a biker, and the sign below reads 'danger traversee de route'.
# Length of true sentences = 15011, length of predicted sentences = 15046
# Test Performance: Loss: 2.3938103513514744, Bleu1: 79.10307222163866, Bleu4: 7.762423939536968
# (2.3938103513514744, 79.10307222163866, 7.762423939536968)

# %%
exp.test(2.0, model400)
# Out:
# loading annotations into memory...
# Done (t=0.44s)
# creating index...
# index created!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sentence for image # 0 in iteration # 0 is: multi stop summer situated with half-filled washington post street . interesting ahead meters advertising records meets boaters roofing bulb, actual: street signs at an intersection of roads in front of a brick building.
# Length of true sentences = 15011, length of predicted sentences = 15649
# Test Performance: Loss: 2.3937329332879247, Bleu1: 64.96013431102779, Bleu4: 4.908686492961965
# (2.3937329332879247, 64.96013431102779, 4.908686492961965)
