# %%
from train_unet import *

# %%
val(0)
# Out:
# Validation epoch 0: avg_iou = 0.010632431871473178, avg_acc = 0.020367118533971763
# 3.302261157178167

# %%
train_loss, val_loss = train()
# Out:
# starting training
# epoch0, iter0, loss: 3.8453798294067383
# epoch0, iter400, loss: 1.0199321508407593
# epoch0, iter800, loss: 0.8644970059394836
# epoch0, iter1200, loss: 1.0987142324447632
# Finish epoch 0, time elapsed 86.98731875419617
# Validation epoch 0: avg_iou = 0.5431816844797847, avg_acc = 0.687022284562908
# --------------------
# epoch1, iter0, loss: 0.9924885630607605
# epoch1, iter400, loss: 0.7057408690452576
# epoch1, iter800, loss: 1.2642391920089722
# epoch1, iter1200, loss: 0.5044550895690918
# Finish epoch 1, time elapsed 90.80258321762085
# Validation epoch 1: avg_iou = 0.5817433661044533, avg_acc = 0.7221199395051643
# --------------------
# epoch2, iter0, loss: 0.602297842502594
# epoch2, iter400, loss: 1.0400885343551636
# epoch2, iter800, loss: 0.4107857942581177
# epoch2, iter1200, loss: 0.7047849297523499
# Finish epoch 2, time elapsed 96.21388387680054
# Validation epoch 2: avg_iou = 0.6165543883594115, avg_acc = 0.751353548044589
# ...

# %%
test()
# Out:
# Final test from best model : avg_iou = 0.6241827294452866, avg_acc = 0.7590623409890417
#  Class wise ious getting saved in Baseline_IOU_Classwise.csv file
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
